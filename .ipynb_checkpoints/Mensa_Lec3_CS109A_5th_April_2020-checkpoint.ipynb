# %%
#Just to verify haha
#the code below I created myself while referencing Havard CS109a Class 
import numpy as np
numpy.__version__
# Out:
# '1.18.1'

# %%
# I have a .csv file containing list of 50 song from billboard
# the initial version was : f = open("data/top50.csv") , but it doesn't work,so I modified
# by adding 'encoding' parameter
# then I read first line from file object

f = open("data/top50.csv", encoding = 'utf8')
f.readline()
# Out:
# ',TrackName,ArtistName,Genre,BeatsPerMinute,Energy,Danceability,Loudness,Liveness,Valence,Length,Acousticness,Speechiness,Popularity\n'

# %%
# I delete white space on the right (\n maybe)
f = open("data/top50.csv", encoding = 'utf8')
f.readline().rstrip()
# Out:
# ',TrackName,ArtistName,Genre,BeatsPerMinute,Energy,Danceability,Loudness,Liveness,Valence,Length,Acousticness,Speechiness,Popularity'

# %%
# here I try to read first line from f - in string form
# remove whitespace on both side - still in string form
# split elements in string by ',' - now I have a list
# the first element is empty '', so I slice from 1

f = open("data/top50.csv", encoding = 'utf8')
column_names = f.readline().strip().split(",")[1:]
column_names
# Out:
# ['TrackName',
#  'ArtistName',
#  'Genre',
#  'BeatsPerMinute',
#  'Energy',
#  'Danceability',
#  'Loudness',
#  'Liveness',
#  'Valence',
#  'Length',
#  'Acousticness',
#  'Speechiness',
#  'Popularity']

# %%
type(f.readline().strip().split(","))
# Out:
# list

# %%
# I create a dataset as list, a list of column name (header), and insert ID header to beginning

dataset = []

f = open("data/top50.csv", encoding = 'utf8')
column_names = f.readline().strip().split(",")[1:]
column_names.insert(0,"ID")

# Process every line in f
# split them to a list of attributes
# use zip function to match them by position a[1] - b[1], a[2] - b[2],...
# then I create dictionary, whose keys is column name, value is attribute
# finally, I  append them to my list dataset
# ?: why line begins from second row in my file ?

for line in f:
    print(line)
    attributes = line.strip().split(",")
    a = dict(zip(column_names, attributes))
    dataset.append(a)
    #a = dict(zip(column_names, attributes))
# Out:
# 1,Senorita,Shawn Mendes,canadian pop,117,55,76,-6,8,75,191,4,3,79
#
# 2,China,Anuel AA,reggaeton flow,105,81,79,-4,8,61,302,8,9,92
#
# 3,boyfriend (with Social House),Ariana Grande,dance pop,190,80,40,-4,16,70,186,12,46,85
#
# 4,Beautiful People (feat. Khalid),Ed Sheeran,pop,93,65,64,-8,8,55,198,12,19,86
#
# 5,Goodbyes (Feat. Young Thug),Post Malone,dfw rap,150,65,58,-4,11,18,175,45,7,94
#
# 6,I Don't Care (with Justin Bieber),Ed Sheeran,pop,102,68,80,-5,9,84,220,9,4,84
#
# 7,Ransom,Lil Tecca,trap music,180,64,75,-6,7,23,131,2,29,92
#
# 8,How Do You Sleep?,Sam Smith,pop,111,68,48,-5,8,35,202,15,9,90
#
# 9,Old Town Road - Remix,Lil Nas X,country rap,136,62,88,-6,11,64,157,5,10,87
#
# 10,bad guy,Billie Eilish,electropop,135,43,70,-11,10,56,194,33,38,95
#
# 11,Callaita,Bad Bunny,reggaeton,176,62,61,-5,24,24,251,60,31,93
#
# 12,Loco Contigo (feat. J. Balvin & Tyga),DJ Snake,dance pop,96,71,82,-4,15,38,185,28,7,86
#
# 13,Someone You Loved,Lewis Capaldi,pop,110,41,50,-6,11,45,182,75,3,88
# ...

# %%
for song in dataset:
    if int(song['Length']) > 240:
        print("{0} - performed by {1}".format(song['TrackName'],song['ArtistName']))
# Out:
# China - performed by Anuel AA
# Callaita - performed by Bad Bunny
# Otro Trago - Remix - performed by Sech
# No Guidance (feat. Drake) - performed by Chris Brown
# LA CANCIÓN - performed by J Balvin
# No Me Conoce - Remix - performed by Jhay Cortez
# Soltera - Remix - performed by Lunay

# %%
# I use operator module to sort my dataset
# I use itemgetter() to get 'popularity' as my key to sort
# !!! : attention to song 40th '[damn],...', its attributes were incorrectly arranged
# !!! : reason : ',' in its name
import operator
sorted(dataset,key= operator.itemgetter('Popularity'),reverse = True)
# Out:
# [{'ID': '10',
#   'TrackName': 'bad guy',
#   'ArtistName': 'Billie Eilish',
#   'Genre': 'electropop',
#   'BeatsPerMinute': '135',
#   'Energy': '43',
#   'Danceability': '70',
#   'Loudness': '-11',
#   'Liveness': '10',
#   'Valence': '56',
#   'Length': '194',
#   'Acousticness': '33',
#   'Speechiness': '38',
#   'Popularity': '95'},
#  {'ID': '5',
#   'TrackName': 'Goodbyes (Feat. Young Thug)',
#   'ArtistName': 'Post Malone',
#   'Genre': 'dfw rap',
#   'BeatsPerMinute': '150',
#   'Energy': '65',
#   'Danceability': '58',
#   'Loudness': '-4',
#   'Liveness': '11',
#   'Valence': '18',
#   'Length': '175',
#   'Acousticness': '45',
#   'Speechiness': '7',
#   'Popularity': '94'},
#  {'ID': '11',
#   'TrackName': 'Callaita',
#   'ArtistName': 'Bad Bunny',
#   'Genre': 'reggaeton',
#   'BeatsPerMinute': '176',
#   'Energy': '62',
#   'Danceability': '61',
#   'Loudness': '-5',
#   'Liveness': '24',
#   'Valence': '24',
#   'Length': '251',
#   'Acousticness': '60',
# ...

# %%
dataset
# Out:
# [{'ID': '1',
#   'TrackName': 'Senorita',
#   'ArtistName': 'Shawn Mendes',
#   'Genre': 'canadian pop',
#   'BeatsPerMinute': '117',
#   'Energy': '55',
#   'Danceability': '76',
#   'Loudness': '-6',
#   'Liveness': '8',
#   'Valence': '75',
#   'Length': '191',
#   'Acousticness': '4',
#   'Speechiness': '3',
#   'Popularity': '79'},
#  {'ID': '2',
#   'TrackName': 'China',
#   'ArtistName': 'Anuel AA',
#   'Genre': 'reggaeton flow',
#   'BeatsPerMinute': '105',
#   'Energy': '81',
#   'Danceability': '79',
#   'Loudness': '-4',
#   'Liveness': '8',
#   'Valence': '61',
#   'Length': '302',
#   'Acousticness': '8',
#   'Speechiness': '9',
#   'Popularity': '92'},
#  {'ID': '3',
#   'TrackName': 'boyfriend (with Social House)',
#   'ArtistName': 'Ariana Grande',
#   'Genre': 'dance pop',
#   'BeatsPerMinute': '190',
#   'Energy': '80',
#   'Danceability': '40',
#   'Loudness': '-4',
#   'Liveness': '16',
#   'Valence': '70',
#   'Length': '186',
#   'Acousticness': '12',
# ...

# %%
dataset [39]
# Out:
# {'ID': '40',
#  'TrackName': '"[damn]',
#  'ArtistName': ' i\'m lonely (with Anne-Marie) - from 13 Reasons Why: Season 3"',
#  'Genre': 'Lauv',
#  'BeatsPerMinute': 'dance pop',
#  'Energy': '95',
#  'Danceability': '56',
#  'Loudness': '81',
#  'Liveness': '-6',
#  'Valence': '6',
#  'Length': '68',
#  'Acousticness': '199',
#  'Speechiness': '48',
#  'Popularity': '7'}

# %%
# Start with panda

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %%
top50 = pd.read_csv('data/top50.csv')

# %%
top50
# Out:
#     Unnamed: 0                                          TrackName        ArtistName             Genre  BeatsPerMinute  Energy  Danceability  Loudness  Liveness  Valence  Length  Acousticness  Speechiness  Popularity
# 0            1                                           Senorita      Shawn Mendes      canadian pop             117      55            76        -6         8       75     191             4            3          79
# 1            2                                              China          Anuel AA    reggaeton flow             105      81            79        -4         8       61     302             8            9          92
# 2            3                      boyfriend (with Social House)     Ariana Grande         dance pop             190      80            40        -4        16       70     186            12           46          85
# ...

# %%
print(top50)
# Out:
#     Unnamed: 0                                          TrackName        ArtistName             Genre  BeatsPerMinute  Energy  Danceability  Loudness  Liveness  Valence  Length  Acousticness  Speechiness  Popularity
# 0            1                                           Senorita      Shawn Mendes      canadian pop             117      55            76        -6         8       75     191             4            3          79
# 1            2                                              China          Anuel AA    reggaeton flow             105      81            79        -4         8       61     302             8            9          92
# 2            3                      boyfriend (with Social House)     Ariana Grande         dance pop             190      80            40        -4        16       70     186            12           46          85
# ...

# %%
top50.head(5)
# Out:
#    Unnamed: 0                        TrackName     ArtistName           Genre  BeatsPerMinute  Energy  Danceability  Loudness  Liveness  Valence  Length  Acousticness  Speechiness  Popularity
# 0           1                         Senorita   Shawn Mendes    canadian pop             117      55            76        -6         8       75     191             4            3          79
# 1           2                            China       Anuel AA  reggaeton flow             105      81            79        -4         8       61     302             8            9          92
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop             190      80            40        -4        16       70     186            12           46          85
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop              93      65            64        -8         8       55     198            12           19          86
# ...

# %%
top50.columns
# Out:
# Index(['Unnamed: 0', 'TrackName', 'ArtistName', 'Genre', 'BeatsPerMinute', 'Energy', 'Danceability', 'Loudness', 'Liveness', 'Valence', 'Length', 'Acousticness', 'Speechiness', 'Popularity'], dtype='object')

# %%
top50.describe()
# Out:
#        Unnamed: 0  BeatsPerMinute     Energy  Danceability   Loudness   Liveness    Valence      Length  Acousticness  Speechiness  Popularity
# count    50.00000       50.000000  50.000000      50.00000  50.000000  50.000000  50.000000   50.000000     50.000000    50.000000   50.000000
# mean     25.50000      120.060000  64.060000      71.38000  -5.660000  14.660000  54.600000  200.960000     22.160000    12.480000   87.500000
# std      14.57738       30.898392  14.231913      11.92988   2.056448  11.118306  22.336024   39.143879     18.995553    11.161596    4.491489
# min       1.00000       85.000000  32.000000      29.00000 -11.000000   5.000000  10.000000  115.000000      1.000000     3.000000   70.000000
# 25%      13.25000       96.000000  55.250000      67.00000  -6.750000   8.000000  38.250000  176.750000      8.250000     5.000000   86.000000
# ...
